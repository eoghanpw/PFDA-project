# %%
import csv
import requests
from io import StringIO
import re
import pandas as pd

# File containing csv URLs.
txt_file = "./download-file-list-daily.txt"

# Dictionary to store the dataframes.
dataframes = {}

# Regex pattern to find the start of useful data in CSV files.
pattern = re.compile(r"^date(?!:)", re.IGNORECASE)

# Columns to import.
columns = ["date", "wdsp"]

# Set index.
index = "date"

# Read the URLs from the txt file and strip newlines.
with open(txt_file) as f:
    csv_urls = [line.strip() for line in f if line.strip()]

# Loop through the URLs.
for url in csv_urls:
    try:
        # Send GET request to the URL.
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Failed to retrieve the CSV file. Status code: {response.status_code}")
            continue
        
        # Treat response content as file-like object.
        csv_content = response.text
        csv_file = StringIO(csv_content)

        # Find the start of useful data by searching for the regex pattern.
        csv_reader = csv.reader(csv_file)
        for row_number, row in enumerate(csv_reader):
            row_string = ",".join(row)
            if pattern.search(row_string):
                print(f"Skipped {row_number} rows in {url}")
                break
        else:
            print(f"Error finding regex pattern: \"{pattern.pattern}\" in {url}")
            continue
        
        # Reset the file pointer and import the data as a DataFrame.
        csv_file.seek(0)  # Rewind the file to the beginning for `pd.read_csv`
        df_name = url.split("webdata/")[-1].rstrip(".csv")  # Derive DataFrame name
        dataframes[df_name] = pd.read_csv(csv_file, skiprows=row_number, index_col=index, usecols=columns)
        print(f"Imported {url} as {df_name}")
    
    except Exception as e:
        print(f"An error occurred while processing {url}: {e}")
# Out:
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly1875.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly1875.csv as dly1875
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly675.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly675.csv as dly675
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly2375.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly2375.csv as dly2375
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly3723.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly3723.csv as dly3723
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly2175.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly2175.csv as dly2175
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly3904.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly3904.csv as dly3904
# Skipped 25 rows in https://cli.fusio.net/cli/climate_data/webdata/dly532.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly532.csv as dly532
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly1375.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly1375.csv as dly1375
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly2075.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly2075.csv as dly2075
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly1475.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly1475.csv as dly1475
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly1775.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly1775.csv as dly1775
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly4935.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly4935.csv as dly4935
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly275.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly275.csv as dly275
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly1575.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly1575.csv as dly1575
# Skipped 14 rows in https://cli.fusio.net/cli/climate_data/webdata/dly1275.csv
# An error occurred while processing https://cli.fusio.net/cli/climate_data/webdata/dly1275.csv: Usecols do not match columns, columns expected but not found: ['wdsp']
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly575.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly575.csv as dly575
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly1975.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly1975.csv as dly1975
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly875.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly875.csv as dly875
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly1175.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly1175.csv as dly1175
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly375.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly375.csv as dly375
# Skipped 14 rows in https://cli.fusio.net/cli/climate_data/webdata/dly175.csv
# An error occurred while processing https://cli.fusio.net/cli/climate_data/webdata/dly175.csv: Usecols do not match columns, columns expected but not found: ['wdsp']
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly1075.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly1075.csv as dly1075
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly518.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly518.csv as dly518
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly775.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly775.csv as dly775
# Skipped 24 rows in https://cli.fusio.net/cli/climate_data/webdata/dly2275.csv
# Imported https://cli.fusio.net/cli/climate_data/webdata/dly2275.csv as dly2275

# %%
dataframes
# Out:
# {'dly1875':              wdsp
#  date
#  26-feb-2010   8.3
#  27-feb-2010   4.3
#  28-feb-2010   4.9
#  01-mar-2010   2.3
#  02-mar-2010   7.1
#  ...           ...
#  27-dec-2024   4.2
#  28-dec-2024   5.0
#  29-dec-2024   9.4
#  30-dec-2024  12.8
#  31-dec-2024  13.0
#
#  [5423 rows x 1 columns],
#  'dly675':              wdsp
#  date
#  08-oct-2003  11.3
#  09-oct-2003  10.7
#  10-oct-2003   6.2
#  11-oct-2003   3.0
#  12-oct-2003   6.8
#  ...           ...
#  27-dec-2024   3.8
#  28-dec-2024   4.6
#  29-dec-2024   9.0
#  30-dec-2024  14.2
#  31-dec-2024  12.1
#
#  [7736 rows x 1 columns],
#  'dly2375':              wdsp
#  date
#  17-sep-1956   7.4
#  18-sep-1956   8.0
#  19-sep-1956  11.4
#  20-sep-1956  17.5
#  21-sep-1956  17.4
#  ...           ...
#  27-dec-2024  10.5
#  28-dec-2024  10.6
#  29-dec-2024  18.2
#  30-dec-2024  24.6
#  31-dec-2024  25.6
#
#  [24943 rows x 1 columns],
#  'dly3723':              wdsp
#  date
#  01-jan-1964
#  02-jan-1964
#  03-jan-1964
#  04-jan-1964
#  05-jan-1964
#  ...           ...
#  27-dec-2024   7.8
#  28-dec-2024   7.9
#  29-dec-2024  14.6
#  30-dec-2024  17.8
#  31-dec-2024  20.2
#
#  [22281 rows x 1 columns],
#  'dly2175':              wdsp
#  date
#  01-jan-1950   9.9
#  02-jan-1950  16.5
#  03-jan-1950  10.2
#  04-jan-1950   7.0
#  05-jan-1950  10.2
#  ...           ...
#  27-dec-2024   5.6
#  28-dec-2024   6.2
#  29-dec-2024   8.5
#  30-dec-2024  14.1
#  31-dec-2024  14.3
#
#  [27378 rows x 1 columns],
#  'dly3904':              wdsp
#  date
#  01-jan-1962   9.2
#  02-jan-1962   5.9
#  03-jan-1962   6.7
#  04-jan-1962   4.5
#  05-jan-1962  12.7
#  ...           ...
#  27-dec-2024   3.7
#  28-dec-2024   3.0
#  29-dec-2024   5.9
#  30-dec-2024  11.7
#  31-dec-2024  19.9
#
#  [23009 rows x 1 columns],
#  'dly532':              wdsp
#  date
#  01-jan-1942  17.2
#  02-jan-1942  15.2
#  03-jan-1942  14.0
#  04-jan-1942  17.0
#  05-jan-1942  13.0
#  ...           ...
#  27-dec-2024   3.7
#  28-dec-2024   5.9
#  29-dec-2024  10.2
#  30-dec-2024  12.3
#  31-dec-2024  14.8
#
#  [30316 rows x 1 columns],
#  'dly1375':              wdsp
#  date
#  10-may-2006   4.9
#  11-may-2006   4.7
#  12-may-2006   4.1
#  13-may-2006   5.6
#  14-may-2006   5.9
#  ...           ...
#  27-dec-2024   4.8
#  28-dec-2024   5.1
#  29-dec-2024  11.4
#  30-dec-2024  13.5
#  31-dec-2024  16.4
#
#  [6811 rows x 1 columns],
#  'dly2075':              wdsp
#  date
#  27-jan-2011   5.0
#  28-jan-2011   2.4
#  29-jan-2011   2.2
#  30-jan-2011   5.3
#  31-jan-2011  15.6
#  ...           ...
#  27-dec-2024   5.8
#  28-dec-2024   9.2
#  29-dec-2024  17.0
#  30-dec-2024  20.9
#  31-dec-2024  21.9
#
#  [5088 rows x 1 columns],
#  'dly1475':              wdsp
#  date
#  06-feb-2008  11.1
#  07-feb-2008  14.7
#  08-feb-2008  13.2
#  09-feb-2008  10.7
#  10-feb-2008   6.4
#  ...           ...
#  27-dec-2024   5.0
#  28-dec-2024   4.9
#  29-dec-2024  10.7
#  30-dec-2024  12.2
#  31-dec-2024  14.8
#
#  [6174 rows x 1 columns],
#  'dly1775':              wdsp
#  date
#  19-sep-2008   0.1
#  20-sep-2008   0.1
#  21-sep-2008   0.1
#  22-sep-2008   0.1
#  23-sep-2008   0.1
#  ...           ...
#  27-dec-2024   3.3
#  28-dec-2024   4.6
#  29-dec-2024   5.9
#  30-dec-2024  13.6
#  31-dec-2024  17.8
#
#  [5947 rows x 1 columns],
#  'dly4935':              wdsp
#  date
#  01-aug-1996
#  02-aug-1996   7.7
#  03-aug-1996   6.6
#  04-aug-1996  11.3
#  05-aug-1996   7.8
#  ...           ...
#  27-dec-2024   6.9
#  28-dec-2024   7.0
#  29-dec-2024  14.2
#  30-dec-2024  15.5
#  31-dec-2024  16.6
#
#  [10378 rows x 1 columns],
#  'dly275':              wdsp
#  date
#  14-aug-2003   6.7
#  15-aug-2003   6.5
#  16-aug-2003   5.7
#  17-aug-2003  16.9
#  18-aug-2003  18.5
#  ...           ...
#  27-dec-2024  11.6
#  28-dec-2024  13.1
#  29-dec-2024  19.9
#  30-dec-2024  26.3
#  31-dec-2024  28.0
#
#  [7759 rows x 1 columns],
#  'dly1575':              wdsp
#  date
#  01-may-1955  19.2
#  02-may-1955  14.2
#  03-may-1955  14.8
#  04-may-1955  19.9
#  05-may-1955  16.0
#  ...           ...
#  27-dec-2024  10.6
#  28-dec-2024  13.5
#  29-dec-2024  23.7
#  30-dec-2024  22.7
#  31-dec-2024  26.5
#
#  [25448 rows x 1 columns],
#  'dly575':             wdsp
#  date
#  11-aug-2003  4.6
#  12-aug-2003  3.5
#  13-aug-2003  3.5
#  14-aug-2003  3.5
#  15-aug-2003  2.4
#  ...          ...
#  27-dec-2024  3.0
#  28-dec-2024  2.0
#  29-dec-2024  4.1
#  30-dec-2024  5.6
#  31-dec-2024  8.9
#
#  [7750 rows x 1 columns],
#  'dly1975':              wdsp
#  date
#  08-sep-2004   6.7
#  09-sep-2004   6.4
#  10-sep-2004   6.3
#  11-sep-2004  14.3
#  12-sep-2004  13.2
#  ...           ...
#  27-dec-2024   3.1
#  28-dec-2024   3.7
#  29-dec-2024   7.2
#  30-dec-2024  10.6
#  31-dec-2024  10.1
#
#  [7412 rows x 1 columns],
#  'dly875':              wdsp
#  date
#  08-nov-1973  17.6
#  09-nov-1973  14.8
#  10-nov-1973  10.4
#  11-nov-1973   9.3
#  12-nov-1973  20.0
#  ...           ...
#  27-dec-2024   3.9
#  28-dec-2024   3.8
#  29-dec-2024   7.9
#  30-dec-2024  10.4
#  31-dec-2024  12.3
#
#  [18682 rows x 1 columns],
#  'dly1175':              wdsp
#  date
#  22-feb-2005  10.4
#  23-feb-2005   7.5
#  24-feb-2005   9.2
#  25-feb-2005   9.2
#  26-feb-2005   6.9
#  ...           ...
#  27-dec-2024   3.9
#  28-dec-2024   5.7
#  29-dec-2024  10.1
#  30-dec-2024  16.8
#  31-dec-2024  17.2
#
#  [7247 rows x 1 columns],
#  'dly375':              wdsp
#  date
#  13-aug-2003
#  14-aug-2003   4.3
#  15-aug-2003   3.3
#  16-aug-2003   3.4
#  17-aug-2003   6.4
#  ...           ...
#  27-dec-2024   5.2
#  28-dec-2024   4.1
#  29-dec-2024   7.5
#  30-dec-2024   9.4
#  31-dec-2024  13.2
#
#  [7739 rows x 1 columns],
#  'dly1075':              wdsp
#  date
#  01-dec-1955  11.5
#  02-dec-1955  12.1
#  03-dec-1955   8.0
#  04-dec-1955   6.3
#  05-dec-1955  16.5
#  ...           ...
#  27-dec-2024   5.5
#  28-dec-2024   4.3
#  29-dec-2024   8.0
#  30-dec-2024  14.0
#  31-dec-2024  25.6
#
#  [21467 rows x 1 columns],
#  'dly518':              wdsp
#  date
#  01-sep-1945  12.0
#  02-sep-1945   7.3
#  03-sep-1945   4.2
#  04-sep-1945   6.2
#  05-sep-1945   4.9
#  ...           ...
#  27-dec-2024   4.7
#  28-dec-2024   4.6
#  29-dec-2024   8.7
#  30-dec-2024   9.7
#  31-dec-2024  14.3
#
#  [28977 rows x 1 columns],
#  'dly775':              wdsp
#  date
#  01-may-2004   9.1
#  02-may-2004   5.8
#  03-may-2004  15.0
#  04-may-2004  27.8
#  05-may-2004  17.4
#  ...           ...
#  27-dec-2024   5.7
#  28-dec-2024   3.0
#  29-dec-2024  10.4
#  30-dec-2024  15.1
#  31-dec-2024  21.6
#
#  [7535 rows x 1 columns],
#  'dly2275':              wdsp
#  date
#  01-jan-1942  15.7
#  02-jan-1942  14.8
#  03-jan-1942  14.6
#  04-jan-1942  14.6
#  05-jan-1942  15.5
#  ...           ...
#  27-dec-2024   6.0
#  28-dec-2024   4.5
#  29-dec-2024   7.5
#  30-dec-2024  12.0
#  31-dec-2024  15.8
#
#  [30315 rows x 1 columns]}
